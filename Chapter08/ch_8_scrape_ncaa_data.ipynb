# %% [markdown]
# ## Grabbing Data

# %% [markdown]
# ## Pull in NCAA Data

# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Create an URL object

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36",
    }

year = 2021
url = f'https://247sports.com/season/2021-football/compositeteamrankings/'
# Create object page
page = requests.get(url, headers = headers)
print(page.text)
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" data-template="responsive" class="twofourseven-site" lang="en-US">
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="format-detection" content="telephone=no"/>
#         <meta name="application-name" content="247Sports" />
#         <meta name="robots" content="max-image-preview:large" />
#         <meta name="msapplication-TileColor" content="#004B82" />
#         <meta name="msapplication-TileImage" content="https://s3media.247sports.com/Content/Img/logo_win8.png" />
#         <title>
#
#
# 2021 Recruit Football Team Rankings
# </title>
#         <link rel="apple-touch-icon" href="https://s3media.247sports.com/Content/Img/247touch.png" />
#         <link href="https://s3media.247sports.com/favicon.ico" type="image/x-icon" rel="shortcut icon" />
#         <link rel="preconnect" href="https://cdn.cookielaw.org" />
#         <link rel="preconnect" href="https://geolocation.onetrust.com" />
#
#             <link rel="preconnect" href="https://production-cmp.isgprivacy.cbsi.com" />
#
#         <link rel="preconnect" href="https://s3media.247sports.com" />
#         <link rel="preconnect" href="https://at.cbsi.com" />
#         <link rel="preconnect" href="https://z.moatads.com" />
#         <link rel="preconnect" href="https://tags.tiqcdn.com" />
#         <link rel="preconnect" href="https://www.google-analytics.com" />
#         <link rel="preconnect" href="https://vidtech.cbsinteractive.com" />
#         <link rel="preconnect" href="https://annoyingacoustics.com" />
#         <meta property="fb:app_id" content="1523983947844395"/>
#
#             <meta property="fb:pages" content="130373190333432" />
#
#
#         <!--[if lt IE 10]>
#             <link href='https://assets.247sports.com/Content/SkyNet/Styles/shared/site.css' rel='stylesheet' type='text/css'>
#             <link href='https://assets.247sports.com/Content/SkyNet/Styles/main/layout.css' rel='stylesheet' type='text/css'>
#         <![endif]-->
#
#
#     <!-- OneTrust CMP -->
#     <script defer src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8" data-domain-script="1587620b-5536-4ad4-8186-7b11a4508dc1"></script>
#
#
# <!-- optanon - standardized api for OneTrust -->
# <script defer src="https://production-cmp.isgprivacy.cbsi.com/dist/optanon-v1.1.0.js" type="text/javascript"></script>
#
# <!-- optanon api bootstrap -->
# <script type="text/javascript">
#     !function(n){var o=window,a="cbsoptanon",c="cmd",d="config";o[a]=o[a]?o[a]:{},o[a][c]=o[a][c]?o[a][c]:[],o[a][d]=o[a][d]?o[a][d]:[],["onIframesReady","onFormsReady","onScriptsReady","onAdsReady"].forEach(function(n){o[a][n]=o[a][n]||function(){var d=arguments;o[a][c].push(function(){o[a][n].apply(o[a],d)})}})}();
#     window.cbsoptanon.config.push({ enableServices: false });
# </script>
#
#
# <!-- Ad Library Script -->
# <script>
#     var immediateUseBidBarrelFunctions = ['auction', 'initialize', 'setTargeting', 'setConfig', 'destroyAllSlots', 'destroySlots', 'on'];
#     (function(a){
#         var w=window,b='BidBarrel',q='queue';w[b]=w[b]?w[b]:{};w[b][q]=w[b][q]?w[b][q]:[];
#         a.forEach(function(z){w[b][z]=w[b][z]||function(){var c=arguments;w[b][q].push(function(r){w[b][z].apply(w[b],c);r()})}});
#     })(immediateUseBidBarrelFunctions);
# </script>
#
#     <script defer src="https://at.cbsi.com/lib/dist/prod/bidbarrel-247sports.min.js?adaptive=true"></script>
#
#
# <!-- Add scripts loaded by CMP -->
# <!-- <script defer src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/plain" class="optanon-category-4"></script>
#
#     <script defer src="https://assets.247sports.com/Scripts/SkyNet/Shared/prebid.js" type="text/plain" class="optanon-category-4"></script>
#
# <script defer src="https://native.sharethrough.com/assets/sfp.js" type="text/plain" class="optanon-category-4"></script>
# <script defer src="https://z.moatads.com/cbsprebidheader506831276743/moatheader.js" type="text/javascript"></script> -->
# <script type="text/javascript">
#
#     function parse(a,b,c){var d=b&&c||0,e=0;for(b=b||[],a.toLowerCase().replace(/[0-9a-f]{2}/g,function(a){e<16&&(b[d+e++]=_hexToByte[a])});e<16;)b[d+e++]=0;return b}function unparse(a,b){var c=b||0,d=_byteToHex;return d[a[c++]]+d[a[c++]]+d[a[c++]]+d[a[c++]]+"-"+d[a[c++]]+d[a[c++]]+"-"+d[a[c++]]+d[a[c++]]+"-"+d[a[c++]]+d[a[c++]]+"-"+d[a[c++]]+d[a[c++]]+d[a[c++]]+d[a[c++]]+d[a[c++]]+d[a[c++]]}function v1(a,b,c){var d=b&&c||0,e=b||[];a=a||{};var f=null!=a.clockseq?a.clockseq:_clockseq,g=null!=a.msecs?a.msecs:(new Date).getTime(),h=null!=a.nsecs?a.nsecs:_lastNSecs+1,i=g-_lastMSecs+(h-_lastNSecs)/1e4;if(i<0&&null==a.clockseq&&(f=f+1&16383),(i<0||g>_lastMSecs)&&null==a.nsecs&&(h=0),h>=1e4)throw new Error("uuid.v1(): Can't create more than 10M uuids/sec");_lastMSecs=g,_lastNSecs=h,_clockseq=f,g+=122192928e5;var j=(1e4*(268435455&g)+h)%4294967296;e[d++]=j>>>24&255,e[d++]=j>>>16&255,e[d++]=j>>>8&255,e[d++]=255&j;var k=g/4294967296*1e4&268435455;e[d++]=k>>>8&255,e[d++]=255&k,e[d++]=k>>>24&15|16,e[d++]=k>>>16&255,e[d++]=f>>>8|128,e[d++]=255&f;for(var l=a.node||_nodeId,m=0;m<6;m++)e[d+m]=l[m];return b?b:unparse(e)}function setCookie(a,b,c){c||(c=new Date),document.cookie=a+"="+b+"; expires="+c.toGMTString()+";domain=.247sports.com; path=/"}function readCookie(a){if(""==document.cookie)return!1;var b,c,d=document.cookie;return a+="=",b=d.indexOf(a),b!=-1&&(b+=a.length,c=d.indexOf(";",b),c==-1&&(c=d.length),unescape(d.substring(b,c)))}function killCookie(a,b,c){var d=readCookie(a);d&&(document.cookie=a+"="+d+"; expires=Fri, 13-Apr-1970 00:00:00 GMT"+(b?";path="+b:"")+(c?";domain="+c:""))}function getValue(a,b){return cookieValue=readCookie(a),findString=b,!!cookieValue&&(namePos=cookieValue.indexOf(findString,0),namePos!=-1&&(valueStart=cookieValue.indexOf("&",namePos+1)+1,valueEnd=cookieValue.indexOf("&",valueStart+1),valueEnd==-1&&(valueEnd=cookieValue.length),valueIs=cookieValue.substring(valueStart,valueEnd),null!=namePos?valueIs:void 0))}var _rng;if(window.crypto&&crypto.getRandomValues){var _rnds8=new Uint8Array(16);_rng=function(){return crypto.getRandomValues(_rnds8),_rnds8}}if(!_rng){var _rnds=new Array(16);_rng=function(){for(var b,a=0;a<16;a++)0===(3&a)&&(b=4294967296*Math.random()),_rnds[a]=b>>>((3&a)<<3)&255;return _rnds}}for(var _byteToHex=[],_hexToByte={},i=0;i<256;i++)_byteToHex[i]=(i+256).toString(16).substr(1),_hexToByte[_byteToHex[i]]=i;var _seedBytes=_rng(),_nodeId=[1|_seedBytes[0],_seedBytes[1],_seedBytes[2],_seedBytes[3],_seedBytes[4],_seedBytes[5]],_clockseq=16383&(_seedBytes[6]<<8|_seedBytes[7]),_lastMSecs=0,_lastNSecs=0;
#
#
#
#     var $tfs = new Object();
#
#     var isGuestCaching = true;
#
#     const jwt = readCookie("JWT");
#     if (isGuestCaching) {
#         //generate guid
#         function guid() {
#             return s4() + s4() + '-' + s4() + '-' + s4() + '-' + s4() + '-' + s4() + s4() + s4();
#         }
#
#         function s4() {
#             return Math.floor((1 + Math.random()) * 0x10000).toString(16).substring(1);
#         }
#
#         //determing if we have atc, asc, or gid.
#         const claims = (jwt && atob(jwt.split('.')[1])) || '{}';
#         const { gid, atc, asc } = claims;
#         if (!atc || !asc || !gid) {
#             window.delayAnalytics = true;
#             var setCookieUrl = '//247sports.com/Guest/ManageMyCookies/';
#             //checks for referer in the url
#             if (location.search.indexOf('referer=')) {
#                 setCookieUrl = setCookieUrl + location.search;
#             }
#
#             var xhttp = new XMLHttpRequest();
#             xhttp.open('GET', setCookieUrl, true);
#             xhttp.onload = function (response) {
#                 const csrf = JSON.parse(response.currentTarget.response).csrf;
#                 window.localStorage.setItem('client-ip', xhttp.getResponseHeader('X-Client-IP'));
#                 if (csrf) {
#                     window.localStorage.setItem('csrf', csrf);
#                     $tfs.csrf = csrf;
#                 }
#                 $tfs.RealIp = xhttp.getResponseHeader('X-Client-IP');
#                 const newJwt = readCookie("JWT");
#                 const newClaims = (newJwt && atob(newJwt.split('.')[1])) || '{}';
#                 const { newAtc, newAsc } = newClaims;
#
#                 $tfs.SessionId = newAsc;
#                 $tfs.TrackingId = newAtc;
#                 $tfs.User.ATC = newAtc;
#                 $tfs.User.Token = newJwt;
#                 $tfs.GuestJWT = readCookie('GUEST_JWT');
#                 window.delayAnalytics = false;
#             };
#             xhttp.send();
#         } else {
#             $tfs.SessionId = asc;
#             $tfs.TrackingId = asc;
#         }
#         var userRequestID = guid();
#     } else {
#         window.delayAnalytics = false;
#     }
#
#     $tfs.LazyLoadAds = true;
#     $tfs.CallApis = true;
#     $tfs.ShowRecirculator = true;
#     $tfs.RequestId = userRequestID;
#     $tfs.CurrentSite =
# {"Key":"33","Alias":"247sports","Name":"247Sports","DefaultUrl":"//247sports.com","Avatar":"https://s3media.247sports.com/Uploads/Site/33/102760.png?fit=bounds\u0026crop=50:50,offset-y0.50\u0026width=50\u0026height=50","CurrentDomain":"247sports.com","Network":"247Sports","NetworkKey":1,"FirstPromoLine":"Fastest-growing network","SecondPromoLine":"Trusted source for college and recruiting news","PrimaryColor":null,"ComponentColor":null,"HighlightColor":null,"LinkColor":null,"BoardCaptcha":"False","EmailSubscriptions":[26,27],"CurrentPromotion":{"ButtonText":"50% off Annual VIP","SubscribeText":"50% off first year","Promo1Text":"50% off Annual VIP Pass first year","Promo2Text":"50% off Annual VIP Pass","IsAllAccessEligible":false},"Institution":{"Name":null,"Mascot":null,"Conference":null,"League":null}}
# ;
#     $tfs.GuestJWT = readCookie('GUEST_JWT');
#
#     $tfs.Guest =  new Object() ;
#     if (isGuestCaching) {
#         $tfs.Guest.Referer = readCookie('referer');
#     }
#
#     $tfs.Recirculator = 'on';
#     $tfs.Related = Array();
#
#         $tfs.RealIp = window.localStorage.getItem('client-ip');
#         $tfs.csrf = window.localStorage.getItem('csrf');
#
#     $tfs.apiurl = "https://ipa.247sports.com";
#     $tfs.flyVideoUrl = 'https://www.cbssports.com/api/content/video/';
#
#     $tfs.buildVersion = 1405;
#     $tfs.defaultChannel = '247sports-national-college-football-nashville-team';
#
#     if (localStorage && localStorage.getItem('tfs-user')) {
#         user = JSON.parse(window.localStorage.getItem('tfs-user'));
#         if (parseInt(readCookie('UID')) === user.Key && user.ExpiresAt > new Date()) {
#             $tfs.User = user;
#             // update UnreadNotifications
#             var url = '//247sports.com/My/ExtendedUser.json';
#             var xhttp = new XMLHttpRequest();
#             xhttp.open('GET', url, true);
#             xhttp.onload = function (response) {
#                 const unreadNotifications = JSON.parse(response.currentTarget.response).UnreadNotifications;
#                 var bells = document.getElementsByClassName('bell');
#                 if (bells && bells.length) {
#                     var bellSpans = bells[0].getElementsByTagName('span');
#                     if (bellSpans && bellSpans.length) {
#                         bellSpans.innerHTML = unreadNotifications > 9 ? '9+' : unreadNotifications;
#                     }
#                 }
#                 $tfs.User.UnreadNotifications = unreadNotifications
#                 window.localStorage.setItem('tfs-user', JSON.stringify($tfs.User));
#             };
#             xhttp.send();
#         } else {
#             localStorage.removeItem('tfs-user');
#         }
#     }
#
#     if (!$tfs.User) {
#         document.write('<scr' + 'ipt type="text/javascript" src="/User/TFS.js"></scr' + 'ipt>');
#     }
# </script>
#
# <!-- Admiral Tag -->
# <script type="text/javascript">
#     !(function(o,n,t){t=o.createElement(n),o=o.getElementsByTagName(n)[0],t.async=1,t.src="https://annoyingacoustics.com/v2qizOMxa-sykrfb7exAI_LlmpXtQrXP0Re37xGV3DHq7-_G6bfnmMcyrgvZDOfnd1Q",o.parentNode.insertBefore(t,o)})(document,"script"),(function(o,n){function t(){(t.q=t.q||[]).push(arguments)}t.v=1,o.admiral=o.admiral||t})(window);!(function(o,t,n,c){function e(n){(function(){try{return(localStorage.getItem("v4ac1eiZr0")||"").split(",")[4]>0}catch(o){}return!1})()&&(n=o[t].pubads())&&n.setTargeting("ae","t")}(c=o[t]=o[t]||{}).cmd=c.cmd||[],typeof c.pubads===n?e():typeof c.cmd.unshift===n?c.cmd.unshift(e):c.cmd.push(e)})(window,"googletag","function");
#
#     var userIsVip = $tfs.User.Status.indexOf('Active') > -1;
#     var vipString = userIsVip.toString();
#     window.admiral("targeting", "set", "vip", vipString);
# </script>
#
#
# <script type="application/ld+json">
#     {
#         "@context": "http://schema.org/",
#         "@graph": [
#             {
#                 "@type": "Organization",
#                 "name": "247Sports",
#                 "description": "Your Team. All The Time.",
#                 "logo": "https://s3media.247sports.com/Content/SkyNet/Img/247sports.png",
#                 "memberOf": {
#                     "@type": "Organization",
#                     "name": "CBS Interactive"
#                 },
#                 "founder": "Shannon Terry",
#                 "foundingDate": "2010",
#                 "url": "https://247sports.com/",
#                 "sameAs": [
#                     "https://www.facebook.com/247Sports/",
#                     "https://twitter.com/247Sports/",
#                     "https://www.instagram.com/247Sports/",
#                     "https://en.wikipedia.org/wiki/247Sports.com"
#                 ],
#                 "address": {
#                     "@type": "PostalAddress",
#                     "streetAddress": "6 Cadillac Drive, Suite 280",
#                     "addressLocality": "Nashville",
#                     "addressRegion": "TN",
#                     "postalCode": "37027",
#                     "addressCountry": "USA"
#                 },
#                 "contactPoint": {
#                     "@type": "ContactPoint",
#                     "contactType": "Customer Support",
#                     "email": "support@247sports.com",
#                     "telephone": "1-888-508-3055"
#                 }
#             }
#
#         ]
#     }
# </script>
#
#
#
# <script>
#     var surround=new Object();
#     surround.cat = ['a','b','c','d','e','f'];
#     surround.cookie = readCookie('surround');
#     xfpDomain = '.'+location.hostname;
#     //xfpEnvironment = "7336";
#     xfpEnvironment = "8264";
#     var xfpObj='vguid='+surround.vguid;
#     if (window.location.search.toLowerCase().indexOf('adnetwork') > 0 && !isNaN(getQueryVariable('adNetwork'))) {
#         var xfpEnvironment = getQueryVariable('adNetwork');
#     }
#
#     if (surround.cookie == false || surround.cookie == undefined) {
#         surround.pick = Math.floor(Math.random() * surround.cat.length);
#         surround.subsession = Math.floor(Math.random() * 4) + 1; /*subsessions 1-4*/
#         document.cookie=("surround="+surround.cat[surround.pick]+"|"+surround.subsession+";domain="+xfpDomain+";path=/" );
#         surround.cookie = readCookie('surround');
#     }
#     if (surround.cookie) {surround.sessions=surround.cookie.split("|");}
#     surround.vguid = v1();  // set the vguid. This requires the code in the block above this one.
#
#     //first page load
#     // tracks if this is the first page the user has visited in this session
#     function xfpFirstPageCookie() {
#         if (xfpFirstPage) {return xfpFirstPage;}           // only run once per page, if already set, just return value
#         var xfpFirstPage = readCookie('XFP_FIRSTPAGE');    // get firstPage cookie
#         if (!xfpFirstPage) {                               // if cookie doesn't exist, this is the first page, so firstPage = 1
#             xfpFirstPage = 1;
#         } else if (xfpFirstPage == 1) {                    // else, this is the second page, set firstPage = 0
#             xfpFirstPage = 0;
#         }
#         var exp = new Date();
#         exp.setTime(exp.getTime() + xfpGetTimeToExpiration(.75)); // get number of milliseconds until 12:45am ET
#         document.cookie=('XFP_FIRSTPAGE ='+xfpFirstPage+";expires="+exp.toUTCString()+";domain="+xfpDomain+";path=/;");
#         return xfpFirstPage;                                // set and return the parameter DVAR_FIRSTPAGE = firstPage
#     }
#
#     function getQueryVariable(variable) {
#         var query = window.location.search.substring(1);
#         var vars = query.split("&");
#         for (var i=0;i<vars.length;i++) {
#             var pair = vars[i].split("=");
#             if(pair[0] == variable){return pair[1];}
#         }
#         return(false);
#     }
#
#     // given the expiration hour in ET, return the number of milliseconds to
#     // expiration from the given Date Object (defaults to current date)
#     function xfpGetTimeToExpiration(etExpireHour,dt) {
#         dt = dt || new Date();
#         var etUtcOffset = 5;                            // hours
#         if (isEDT(dt)) etUtcOffset = 4;                 // if in daylight savings time
#         var utcExpire = (etExpireHour+etUtcOffset)%24;  // UTC expire time in hours
#         var utcTime = 60*dt.getUTCHours() + dt.getUTCMinutes(); // UTC time in mins
#         var minsToExpiration = 60*utcExpire - utcTime;  // time to expiration
#         if (minsToExpiration < 0) minsToExpiration = 24*60 + minsToExpiration;
#         return 60000*minsToExpiration;                  // in milliseconds
#     }
#
#     // determine if Daylight Savings Time is being observed in the ET timezone
#     //   at the date/time of the given Date Object (defaults to current time)
#     function isEDT(dt) {
#         dt = dt || new Date();          // default to current date
#         var month = dt.getUTCMonth();   // get month in UTC
#         if (month > 2 && month < 10) return true;   // in EDT if Apr to Oct
#         if (month < 2 || month > 10) return false;  // not in EDT if Jan,Feb,Dec
#         var date = dt.getUTCDate();     // get day of month in UTC
#         var day = dt.getUTCDay();       // get day of week in UTC
#         if (month == 10) {              // November
#             if (date > 7) return false; // after first week, not in EDT
#             if (day == 0) {             // Sunday of first week, check time
#                 if (dt.getUTCHours() < 6) return true; //before 6am UTC, in EDT
#                 return false;           // 6am UTC or later, not in EDT
#             }
#             if (date > day) return false; // Sunday has passed, not in EDT
#             return true;                // Sunday has not passed, in EDT
#         }
#
#         // March
#         if (date < 8) return false; // still first week, not in EDT
#         if (date > 14) return true; // after second week, in EDT
#         if (day == 0) {             // Sunday of second week, check time
#             if (dt.getUTCHours() > 6) return true; // 7am UTC or later, in EDT
#             return false;           // before 7am UTC, not in EDT
#         }
#         if (date - day > 7) return true;  // Sunday has passed, in EDT
#         return false; // Sunday has not passed, not in EDT
#     }
#
#     var xfpFirstPage =  xfpFirstPageCookie();
#     var xfpSession    = (surround.cookie) ? surround.sessions[0] : 'off';
#     var xfpSubsession = (surround.cookie) ? surround.sessions[1] : 'off';
#
#     function xfpGetArgs(){
#         var args = new Object();
#         var query = location.search.substring(1); // get query string
#         var pairs = query.split("&");
#         for (var i=0; i < pairs.length; i++) {
#             var pos = pairs[i].indexOf('=');             // Look for name "name=value"
#             if (pos == -1) continue;                     // If not found, skip
#             var argname = pairs[i].substring(0,pos);     // Extract the name
#             var value   = pairs[i].substring(pos+1);     // Extract the value
#             value = decodeURIComponent(value);           // Decode it, if needed
#             var adTarg = argname.match(/adTargeting_/);  // Do we have a match on adTargeting_<key>
#
#             // Set Targeting for spec'd out query parms
#             if (argname == 'env' || argname == 'session' || argname == 'subses' || argname == 'adRegion' || argname == 'ftag' || argname == 'ttag' || (adTarg)) {
#                 // args[argname] = value;
#                 if (adTarg) {argname = argname.substring(12);}    // strip off adTargeting_ from the name if present
#                 if (argname == 'ftag' || argname == 'ttag') {
#                     document.cookie=("xfpFtag="+value+";domain="+xfpDomain+";path=/" );
#                     newFtag = 1;
#                 }
#                 xfpObj += '~' +argname +'=' +value;
#             }
#         }
#         var xfpFtagVal = readCookie("xfpFtag");                   // check if we have an ftag cookie
#         var newFtag = 0;
#         if ((newFtag==0) && xfpFtagVal) {                         // If no new setting for ftag but we had an old one then
#             xfpObj += '~ftag=' +xfpFtagVal;
#         }
#     }
#
#     //google dfp tag
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     if (window.location.search.toLowerCase().indexOf('utm_medium=newsletter') > 0) {
#         sessionStorage.setItem('xfpReferrer', 'newsletter');
#     }
#
#     if (sessionStorage.getItem('xfpReferrer') !== null) {
#         var xfpReferrer = "newsletter";
#     } else if (typeof document.referrer !== 'undefined' && document.referrer != '') {
#         if (document.referrer.match(/^https?:\/\/([^\/]+\.)?facebook\.com(\/|$)/i)) {
#             var xfpReferrer = "fb";
#         }
#     }
#
#     var xfpEnv = "prod";
#
#
#     function isFaceBookApp() {
#         return /FBAV|FBAN|FBIOS|GSA|MOBILE|iPhone/i.test(navigator.userAgent);
#     }
#     var tfsMobile = true;
#     tfsMobile = (Math.max(document.documentElement.clientWidth, window.innerWidth || 0) < 900) || isFaceBookApp();
#     var tfsNetwork = '247sports';
#     var tfsMedium = (tfsMobile ? 'maw-' : 'aw-') + tfsNetwork;
#     var tfsPageSite = '';
#     if ($tfs.CurrentSite.Institution.Name != null) {
#         tfsPageSite = $tfs.CurrentSite.Institution.Name + ($tfs.CurrentSite.Institution.Mascot != null ? ('_' + $tfs.CurrentSite.Institution.Mascot) : '');
#     } else {
#         tfsPageSite = tfsNetwork;
#     }
#     tfsPageSite = tfsPageSite.replace(/\([^)]*\)|\s|'|\&/g,'').replace(/\.|-/g ,'_').toLowerCase();
#
#     $tfs.AdConfig = {
#         bidders: {
#             "omni_skybox_leader_sticky":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "3984116" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012969 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256356 } },
#                 { "bidder": "ix", "params": { "siteId": '171213', "size": [728,90] } },
#                 { "bidder": "openx", "params": { "unit": '538597546', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1056 } },
#                 { "bidder": "sonobi" }
#             ],
#             "leader_top2":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715767" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012969 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256356 } },
#                 { "bidder": "ix", "params": { "siteId": '173554', "size": [728,90] } },
#                 { "bidder": "openx", "params": { "unit": '539475265', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1051 } },
#                 { "bidder": "sonobi" }
#             ],
#             "leader_middle2":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715766" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012969 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256356 } },
#                 { "bidder": "ix", "params": { "siteId": '173551', "size": [728,90] } },
#                 { "bidder": "openx", "params": { "unit": '539475266', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1053 } },
#                 { "bidder": "sonobi" }
#             ],
#             "leader_middle3":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715769" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012969 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256356 } },
#                 { "bidder": "ix", "params": { "siteId": '173553', "size": [728,90] } },
#                 { "bidder": "openx", "params": { "unit": '539475267', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1054 } },
#                 { "bidder": "sonobi" }
#             ],
#             "leader_bottom2":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715765" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012969 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256356 } },
#                 { "bidder": "ix", "params": { "siteId": '173552', "size": [728,90] } },
#                 { "bidder": "openx", "params": { "unit": '539475264', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1050 } },
#                 { "bidder": "sonobi" }
#             ],
#             "leader_bottom3":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715767" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012969 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256356 } },
#                 { "bidder": "ix", "params": { "siteId": '173554', "size": [728,90] } },
#                 { "bidder": "openx", "params": { "unit": '539475265', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1051 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mpu_plus_top":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "3984117" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012968 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256353 } },
#                 { "bidder": "ix", "params": { "siteId": '171839', "size": [300,250] } },
#                 { "bidder": "openx", "params": { "unit": '538597539', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1045 } },
#                 { "bidder": "sonobi" }
#             ],
#             "native_top":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4861937" } },
#                 { "bidder": "appnexus", "params": { "placementId": 13600913 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256353 } },
#                 { "bidder": "ix", "params": { "siteId": '281938', "size": [300,250] } },
#                 { "bidder": "openx", "params": { "unit": '540163828', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1044 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mpu_flex_inc":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4861937" } },
#                 { "bidder": "appnexus", "params": { "placementId": 13600913 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256353 } },
#                 { "bidder": "ix", "params": { "siteId": '281938', "size": [300,250] } },
#                 { "bidder": "openx", "params": { "unit": '540163828', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx" },
#                 { "bidder": "sonobi" }
#             ],
#             "mpu_middle":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "3984123" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012968 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256353 } },
#                 { "bidder": "ix", "params": { "siteId": '171840', "size": [300,250] } },
#                 { "bidder": "openx", "params": { "unit": '538597538', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1044 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mpu_bottom":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "3984118" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012968 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256353 } },
#                 { "bidder": "ix", "params": { "siteId": '171841', "size": [300,250] } },
#                 { "bidder": "openx", "params": { "unit": '538597537', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "sonobi" }
#             ],
#             "sky_top":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "3984115" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012970 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256352 } },
#                 { "bidder": "ix", "params": { "siteId": '171842', "size": [160,600] } },
#                 { "bidder": "openx", "params": { "unit": '539475263', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1040 } },
#                 { "bidder": "sonobi" }
#             ],
#             "sky_middle":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "5005181" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012970 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256352 } },
#                 { "bidder": "ix", "params": { "siteId": '171843', "size": [160,600] } },
#                 { "bidder": "openx", "params": { "unit": '539475262', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1039 } },
#             ],
#             "sky_middle2":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715771" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012970 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256352 } },
#                 { "bidder": "ix", "params": { "siteId": '173555', "size": [160,600] } },
#                 { "bidder": "openx", "params": { "unit": '539475260', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1037 } },
#                 { "bidder": "sonobi" }
#             ],
#             "sky_middle3":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715770" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012970 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256352 } },
#                 { "bidder": "ix", "params": { "siteId": '173557', "size": [160,600] } },
#                 { "bidder": "openx", "params": { "unit": '539475261', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1038 } },
#                 { "bidder": "sonobi" }
#             ],
#             "sky_bottom":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "3984120" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012970 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256352 } },
#                 { "bidder": "ix", "params": { "siteId": '171844', "size": [160,600] } },
#                 { "bidder": "openx", "params": { "unit": '539475259', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1036 } },
#                 { "bidder": "sonobi" }
#             ],
#             "sky_bottom2":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715768" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012970 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256352 } },
#                 { "bidder": "ix", "params": { "siteId": '173556', "size": [160,600] } },
#                 { "bidder": "openx", "params": { "unit": '539475257', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1034 } },
#                 { "bidder": "sonobi" }
#             ],
#             "sky_bottom3":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715764" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012970 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256352 } },
#                 { "bidder": "ix", "params": { "siteId": '173558', "size": [160,600] } },
#                 { "bidder": "openx", "params": { "unit": '539475258', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1035 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_omni_skybox_plus_sticky":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "3984124" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012972 } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256355 } },
#                 { "bidder": "kargo", "params": { "placementId": '_m33qqVnD6l' } },
#                 { "bidder": "ix", "params": { "siteId": '171845', "size": [320,50] } },
#                 { "bidder": "openx", "params": { "unit": '538597548', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1049 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_mpu_flex_top":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "3984125" } },
#                 { "bidder": "appnexus", "params": { "placementId": 9012971 } },
#                 { "bidder": "audienceNetwork", "params": { "placementId": '208765682892700_208767306225871' } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256354 } },
#                 { "bidder": "ix", "params": { "siteId": '171848', "size": [300,250] } },
#                 { "bidder": "kargo", "params": { "placementId": '_pfflK7xnRW' } },
#                 { "bidder": "openx", "params": { "unit": '538597547', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1046 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_flex_top":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "3984125" } },
#                 { "bidder": "appnexus", "params": { "placementId": 13600918 } },
#                 { "bidder": "audienceNetwork", "params": { "placementId": '208765682892700_208767306225871' } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256354 } },
#                 { "bidder": "ix", "params": { "siteId": '171848', "size": [300,250] } },
#                 { "bidder": "kargo", "params": { "placementId": '_pfflK7xnRW' } },
#                 { "bidder": "openx", "params": { "unit": '538597547', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1046 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_mpu_flex_inc":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4861940" } },
#                 { "bidder": "appnexus", "params": { "placementId": 13600916 } },
#                 { "bidder": "audienceNetwork", "params": { "placementId": '208765682892700_255669731535628' } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256354 } },
#                 { "bidder": "ix", "params": { "siteId": '281939', "size": [300,250] } },
#                 { "bidder": "kargo", "params": { "placementId": '_pfflK7xnRW' } },
#                 { "bidder": "openx", "params": { "unit": '540163861', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx" },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_flex_banner_middle":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715772" } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256355 } },
#                 { "bidder": "ix", "params": { "siteId": '171847', "size": [320,50] } },
#                 { "bidder": "openx", "params": { "unit": '539478385', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1048 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_flex_banner_middle2":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715772" } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256355 } },
#                 { "bidder": "ix", "params": { "siteId": '171847', "size": [320,50] } },
#                 { "bidder": "openx", "params": { "unit": '539478385', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1048 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_flex_banner_middle3":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715772" } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256355 } },
#                 { "bidder": "ix", "params": { "siteId": '171847', "size": [320,50] } },
#                 { "bidder": "openx", "params": { "unit": '539478385', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1048 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_flex_banner_middle4":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715774" } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256355 } },
#                 { "bidder": "ix", "params": { "siteId": '171847', "size": [320,50] } },
#                 { "bidder": "openx", "params": { "unit": '539478384', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1047 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_flex_banner_middle5":[
#                 { "bidder": "aol","params": { "network": "9928.1", "placement": "4715774" } },
#                 { "bidder": "criteo", "params": { "zoneId": 1256355 } },
#                 { "bidder": "ix", "params": { "siteId": '171847', "size": [320,50] } },
#                 { "bidder": "openx", "params": { "unit": '539478384', "delDomain": 'cbsi-d.openx.net' } },
#                 { "bidder": "trustx", "params": { "uid": 1047 } },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_mpu_middle":[
#                 { "bidder": "ix", "params": { "siteId": '171849', "size": [300,250] } },
#                 { "bidder": "kargo", "params": { "placementId": '_pfflK7xnRW' } },
#                 { "bidder": "sonobi" }
#             ],
#             "mobile_mpu_middle2":[
#                 { "bidder": "criteo", "params": { "zoneId": 1256354 } },
#                 { "bidder": "trustx", "params": { "uid": 1043 } },
#                 { "bidder": "sonobi" }
#             ]
#         },
#         incrementals: {
#             trustx: {
#                 "mpu_flex_inc":[
#                     6086
#                 ],
#                 "mobile_mpu_flex_inc":[
#                     6085
#                 ]
#             }
#         }
#     };
# </script>
#
# <!-- Facebook Pixel -->
# <script type="text/plain" class="optanon-category-4">
#     if(typeof fbq === 'undefined') {
#         !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#         n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.defer=1;
#         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#         document,'script','https://connect.facebook.net/en_US/fbevents.js');
#         fbq('set', 'autoConfig', false, '320233411816140');
#         fbq('set', 'autoConfig', false, '1575186632756631');
#         fbq('init', '320233411816140');
#         fbq('init', '1575186632756631');
#         fbq('track', 'PageView');
#     }
# </script>
#
# <noscript><img height="1" width="1" style="display:none"
# src="https://www.facebook.com/tr?id=1575186632756631&ev=PageView&noscript=1"
# /></noscript>
#
# <script defer src="https://assets.247sports.com/Scripts/SkyNet/Shared/detect.js?v=1"></script>
# <script>
#     var sp_abd = 'false';
#     document.addEventListener('sp.blocking', function (e) {
#         sp_abd = 'true';
#         googletag.cmd.push(function() {
#             BidBarrel.setTargeting('st', '1');
#         });
#     });
# </script><link href="https://247sports.com/season/2021-football/compositeteamrankings/" rel="canonical" />
#
#         <style> html { display:none; } </style>
#         <script>
#             if (self == top) {
#                 document.documentElement.style.display = 'block';
#             } else {
#                 top.location = self.location;
#             }
#         </script>
#         <noscript><style>html { display:block; }</style></noscript>
#
#
#
#
# <meta content="2021 Recruit Football Team Rankings" property="og:title" />
#     <meta property="og:type" content="website" />
#     <meta content="https://247sports.com/Season/2021-Football/CompositeTeamRankings/?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50" property="og:url" />
#     <meta property="og:image" content="https://s3media.247sports.com/Content/247Sports/Img/Default/25_default.png" />
#     <meta property="og:site_name" content="247Sports" />
#     <meta property="og:description" content="In order to create the most comprehensive Team Recruiting Ranking without any notion of bias, 247Sports Team Recruiting Ranking is solely based on the 247Sports Composite Rating." />
#
#     <meta name="twitter:card" content="summary" />
#     <meta name="twitter:site" content="247Sports" />
#     <meta name="twitter:title" content="2021 Recruit Football Team Rankings" />
#     <meta name="twitter:description" content="In order to create the most comprehensive Team Recruiting Ranking without any notion of bias, 247Sports Team Recruiting Ranking is solely based on the 247Sports Composite Rating." />
#
#     <meta content="https://s3media.247sports.com/Uploads/Site/33/102760.png" name="twitter:image" />
#     <meta content="https://247sports.com/Season/2021-Football/CompositeTeamRankings/?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50" name="twitter:url" />
#
# <meta content="In order to create the most comprehensive Team Recruiting Ranking without any notion of bias, 247Sports Team Recruiting Ranking is solely based on the 247Sports Composite Rating." name="description" />
#     <link href="https://s3media.247sports.com/Uploads/Assets/592/649/4649592.png" rel="image_src" />
#     <link href="247Sports Default Site Url/Season/2021-Football/CompositeTeamRankings.atom" />
#
# <script>
#     var tfsPageArena = 'collegefootball';
#     var tfsPageType = 'rankings';
#     var tfsSubPageType = 'teamrankings';
#     var tfsRecruiting = 'true';
#     var pageAds = [
#         { name: 'mobile_omni_skybox_plus_sticky', sizes: [[5, 5], [6, 6], [320, 50]], pos: 'top', device: 'mobile', status: 2 },
#         { name: 'omni_skybox_leader_sticky', sizes: [[5, 5], [728, 90], [970, 66], [970, 90]], pos: 'top', device: 'desktop', status: 3 },
#         { name: 'mpu_plus_top', sizes: [[300, 250]], pos: 'top', device: 'desktop', status: 3 },
#         { name: 'image_top', sizes: [[4, 4]], pos: 'top', status: 1 },
#         { name: 'mpu_middle', sizes: [[300, 250]], pos: 'middle', device: 'desktop', status: 2 },
#         { name: 'mpu_bottom', sizes: [[300, 250]], pos: 'bottom', device: 'desktop', status: 2 },
#         { name: 'intromercial', sizes: [[1, 1]], outOfPage: true, status: 3 }
#     ];
# </script>
#
#
#         <link href="https://assets.247sports.com/site/minify.css?type=css&amp;v=1405&amp;files=/content/skynet/styles/bundle/vendor.bundle.css,/content/skynet/styles/shared/style.css,/content/skynet/styles/shared/global.css,/content/skynet/styles/shared/site.css,/content/skynet/styles/bundle/timerlist.bundle.css,/content/skynet/styles/bundle/menu.bundle.css,/content/skynet/styles/bundle/menusearch.bundle.css,/content/skynet/styles/main/layout.css,/content/247sports/styles/main/site.css,/content/skynet/styles/embeds/playerembed.css,/content/skynet/styles/embeds/playerpredictionembed.css" rel="stylesheet" type="text/css" /><link href="https://assets.247sports.com/site/minify.css?type=css&amp;v=1405&amp;files=/content/skynet/styles/bundle/teamranking.bundle.css" rel="stylesheet" type="text/css" /><link href="https://assets.247sports.com/Content/SkyNet/Styles/Sites/Site33.css?v=1405" rel="stylesheet" type="text/css" /><!--[if lt IE 9]><script src="https://assets.247sports.com/scripts/SkyNet/shared/html5.js" type="text/javascript"></script><![endif]--><!--[if lt IE 10]><link href="https://assets.247sports.com/Content/SkyNet/Styles/shared/ie.css" media="screen" rel="stylesheet" type="text/css" /><![endif]-->
#         <noscript><style>.jsonly { display: none; }</style></noscript>
#     </head>
#
#     <body class="season_20211 simplemodellist_pg rm" style="display: block !important;">
#         <script type="text/javascript">
#             var className = $tfs.User.HasActiveAnnual ? 'subscribe' : 'nonsubscribe';
#             var body = document.body;
#             if (body.classList) {
#                 body.classList.add(className);
#             } else {
#                 body.className += ' ' + className;
#             }
#         </script>
#
#             <div class="adhesion-block" data-skybox="mobile">
#                 <div id="mobile_omni_skybox_plus_sticky" data-ad="mobile_omni_skybox_plus_sticky" class="dfp_ad ad-top-strip"></div>
#                 <div id="omni_skybox_leader_sticky" data-ad="omni_skybox_leader_sticky" class="dfp_ad ad-top-strip"></div>
#             </div>
#
#
#         <div id="intromercial" data-ad="intromercial" width="1" height="1"></div>
#
#         <section class="main-wrapper">
#
#
# <header class="topnav">
#
#
#
#
# <div class="network-bar clearfix" id="networkBar">
#     <div class="network-block">
#         <ul class="network-bar-list h_lst">
#
#                 <li><a href="https://247sports.com/League/NCAA-FB/Teams/" title="NCAAF Teams">Teams</a></li>
#
#             <li><a href="https://cbssports.com/" target="_blank">CBS Sports</a></li>
#             <li><a href="https://www.cbssports.com/live/" target="_blank">CBS SPORTS HQ</a></li>
#             <li><a href="https://sportsline.com/" target="_blank">SportsLine</a></li>
#             <li><a href="http://maxpreps.com/" target="_blank">MaxPreps</a></li>
#
#
#             <li data-react="betting-link" class="hidden desktop"></li>
#
#
#                 <li><a data-js="sportsline-fanshop" href="https://fanatics.ncw6.net/oeR27b" rel="nofollow" target="_blank">Shop</a></li>
#
#                 <li>
#                     <a href="https://www.stubhub.com/?gcid=chAFF-_-geoUS-_-genAllTix-_-dt170502-_-cmpHeaderteams-_-part247Sports" class="stubhub-tracker" data-stubhub-element="247Sports Global Nav" target="_blank" rel="nofollow">StubHub</a>
#                 </li>
#
#         </ul>
#     </div>
#     <div class="social-block">
#         <span>Follow 247Sports</span>
#         <ul class="h_lst nav-social-lst">
#             <li class="fb"><a href="https://www.facebook.com/247Sports/" title="Facebook" target="_blank"><b class="icon-facebook"></b><span class="hidden">Facebook</span></a></li>
#             <li class="tw"><a href="https://twitter.com/247Sports/" title="Twitter" target="_blank"><b class="icon-twitter"></b><span class="hidden">Twitter</span></a></li>
#             <li class="ig"><a href="https://www.instagram.com/247Sports/" title="Instagram" target="_blank"><b class="icon-instagram"></b><span class="hidden">instagram</span></a></li>
#
#         </ul>
#     </div>
# </div>
#
#     <div class="nav-bar" id="navBar">
#
#
# <div class="nav-bar__logo-wrapper">
#
# ...
#                 </svg>
#
#             </a>
#         </li>
#     </ul>
#
#     <ul class="footer-links-list">
#         <li><a href="https://247sports.com/Article/About-CBT-Sports-LLC-dba-247Sports-116092" title="About 247Sports">About</a></li>
#         <li><a href="https://247sports.com/Article/Customer-Support-3619" title="Contact Us">Contact Us</a></li>
#         <li><a href="https://www.cbsinteractive.com/brands" title="Advertisers" target="_blank" rel="noopener noreferrer">Advertisers</a></li>
#         <li><a href="https://help.247sports.com/s/" title="Help Center">Help Center</a></li>
#         <li><a href="https://www.cbsinteractive.com/careers" title="Careers" target="_blank" rel="noopener noreferrer">Careers</a></li>
#         <li><a href="https://www.viacomcbsprivacy.com/policy" title="Privacy Policy" target="_blank" rel="noopener noreferrer">Privacy Policy</a></li>
#         <li><a href="https://legalterms.cbsinteractive.com/terms-of-use" title="Terms of Service" target="_blank" rel="noopener noreferrer">Terms of Service</a></li>
#         <li><a href="https://www.cbsinteractive.com/legal/cbsi/terms-of-use/247sports" target="_blank" rel="noopener noreferrer" title="Terms of Use">Terms of Use</a></li>
#         <li><a href="/User/ToggleMobile" title="toggle mobile" data-js="togglemedium" rel="nofollow">Toggle Full/Mobile</a></li>
#     </ul>
#     <ul class="footer-links-list">
#         <li><a href="https://www.viacomcbsprivacy.com/cookies" title="Cookies Policy" target="_blank" rel="noopener noreferrer">Cookies Policy</a></li>
#         <li><a class="ot-sdk-show-settings ccpa-link" title="Do Not Sell Info" target="_blank" rel="noopener noreferrer">Do Not Sell My Personal Information</a></li>
#     </ul>
#
#     <p class="footer-text">
#         &copy; 2005-2022 CBS INTERACTIVE ALL RIGHTS RESERVED. CBS Sports is a registered trademark of CBS Broadcasting Inc.
#     </p>
# </footer>
# <div class="hidden" data-value="89" id="daol"></div>
#
#         <a class="timerlist_anc nimda" data-src="AC13CAF34E4AFDFE17F5BEB2A3BB21715D07302EED1F858A963ADCDF702A69049D078A72811711B6CED8FB82293FAEAFB825426D98250A0A50A059E32125D32B24FD2ADDCA38C7E88807E305309A4F9D" href="#" id="timerlistload">Timer List</a>
#         <section name="timerlist" data-react-component="timerlist"></section>
#
#
#         <div id="image_top" data-ad="image_top"></div>
#         <script src="https://assets.247sports.com/site/minify.js?type=javascript&amp;v=1405&amp;files=/scripts/skynet/shared/aws-sdk-2.176.0.min.js,/scripts/skynet/shared/jquery-1.7.2.min.js,/scripts/skynet/shared/jquery-ui-1.8.1.min.js,/scripts/skynet/shared/jquery.scroll.min.js,/scripts/skynet/shared/jquery.linkify.js,/scripts/skynet/shared/jquery.form.js,/scripts/skynet/shared/jquery.file.js,/scripts/skynet/shared/jquery.fancybox.js,/scripts/skynet/shared/jquery.tokeninput.js,/scripts/skynet/shared/jquery.json.min.js,/scripts/skynet/shared/jquery.timepicker.js,/scripts/skynet/shared/modernizer.js,/scripts/skynet/shared/global.js,/scripts/skynet/shared/skybox.js,/scripts/skynet/shared/site.js,/scripts/skynet/user/register.js,/scripts/skynet/bundle/menu.bundle.js,/scripts/skynet/bundle/menusearch.bundle.js,/scripts/skynet/bundle/config.bundle.js,/scripts/skynet/bundle/timerlist.bundle.js" type="text/javascript"></script><script src="https://assets.247sports.com/scripts/skynet/bundle/vendor.bundle.js?v=1405" type="text/javascript"></script><script src="https://assets.247sports.com/scripts/skynet/bundle/react.bundle.js?v=1405" type="text/javascript"></script><script src="https://assets.247sports.com/scripts/skynet/bundle/polyfills.bundle.js?v=1405" type="text/javascript"></script><script src="https://assets.247sports.com/site/minify.js?type=javascript&amp;v=1405&amp;files=/scripts/skynet/bundle/teamranking.bundle.js" type="text/javascript"></script>
#
#
# <!-- analytics/_simplecomponent.ascx -->
#
#
# <script type="text/plain" class="optanon-category-2">
#     // TODO: move this to an external file and have all instances use it.
#     // TODO: move tealium at the same time
#     // TODO: get all data standardized
#
#     // Google analytics
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#         // TODO: Remove check once after site falls out of cache
#     ga('create', 'UA-17227176-9', '247sports.com');
#     ga('require', 'displayfeatures');
#     ga('set', 'userId', $tfs.User.RegId);
#
#     var arena = typeof(tfsPageArena) != 'undefined' ? tfsPageArena : null;
#     var pageType = typeof(tfsPageType) != 'undefined' ? tfsPageType : null;
#     var site = typeof(tfsPageSite) != 'undefined' ? tfsPageSite : null;
#     var author = null;
#     var authorName = null;
#     var contentType = null;
#     var vip = null;
#
#     var articleType = 'boardpost';
#     if (typeof firstArticleJson !== 'undefined') {
#         articleType = firstArticleJson.typeString;
#     }
#
#
#     if (typeof($tfs.Content) != 'undefined') {
#         author = $tfs.Content.Author;
#         authorName = $tfs.Content.AuthorName;
#         contentType = articleType;
#         vip = $tfs.Content.VIP && $tfs.Content.VIP !== 'False' ? '1' : '0';
#     }
#
#
#     if (typeof firstArticleJson === 'undefined'){
#         ga('send', 'pageview', {
#             'dimension2': arena,
#             'dimension3': pageType,
#             'dimension4': site,
#             'dimension5': author,
#             'dimension6': contentType,
#             'dimension8': $tfs.User.Status,
#             'dimension10': authorName,
#             'dimension11': `${$tfs.CurrentSite.Key}`,
#             'dimension12': vip
#         });
#     }
#
#
#     //quantcast
#     var _qevents = _qevents || [];
#     (function () {
#         var elem = document.createElement('script');
#         elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
#         elem.async = true;
#         elem.type = "text/javascript";
#         elem.onload = function(){
#             // attach the asynchronous pixel handler
#             __qc.async = function(){
#                 __qc.qpixelsent = [];
#                 _qevents.push({
#                     qacct: __qc.qopts.qacct
#                 });
#                 __qc.firepixels();
#             }
#         };
#         var scpt = document.getElementsByTagName('script')[0];
#         scpt.parentNode.insertBefore(elem, scpt);
#     })();
#     _qevents.push({ qacct: "p-4bFzyj4g9rit2", uid: "' + $tfs.User.Key + '" });
# </script>
#
#
# <!-- Ad Block Checker -->
# <script src="https://assets.247sports.com/Scripts/SkyNet/Shared/ads.js"></script>
#
# <!-- Can only run in the us -->
# <script defer src="https://assets.247sports.com/scripts/skynet/shared/heatmap.js"></script>
#
# <script>
#     //newsletter
#     var updateNewsletter = function () {
#         if ($tfs.Guest.EmailSubscriptions == null) {
#             $tfs.Guest.EmailSubscriptions = [];
#         }
#         if ($tfs.User.Status != "Guest") {
#             $tfs.Guest.EmailSubscriptions = $tfs.User.EmailSubscriptions;
#             $tfs.Guest.Newsletter = $tfs.User.Newsletter;
#         }
#
#         if ($tfs.Guest.Newsletter == "Unsubscribed") {
#             var hasSubscribed = false;
#             for (newsletter in $tfs.CurrentSite.EmailSubscriptions) {
#                 if ($tfs.Guest.EmailSubscriptions.indexOf($tfs.CurrentSite.EmailSubscriptions[newsletter]) > -1) {
#                     hasSubscribed = true;
#                     break;
#                 }
#             }
#
#             if (hasSubscribed) {
#                 $tfs.Guest.Newsletter = "Subscribed";
#             }
#         }
#
#         if ($(location).attr('pathname').toLowerCase() === '/distribution/signup') {
#             $tfs.Guest.Newsletter = "OptedOut";
#         }
#     };
#
#     // Adblock check
#     if (window.canRunAds === undefined){
#         $tfs.User.AdBlock = true;
#         document.body.setAttribute('data-adblock', "true");
#     }
# </script>
#
# <script>
#     //Start of tealium tag manager setup
#     if (document.cookie.indexOf('247_geo') == -1) {
#         if (window.heatmap) {
#             var countryCode = 'US';
#         } else {
#             var countryCode = 'not-US';
#         }
#         var date = new Date;
#         date.setFullYear(date.getFullYear() + 1);
#         $247Global.setCookie('247_geo', countryCode, date);
#     }
#
#     if (typeof(tfsMobile) != 'undefined' && tfsMobile) {
#         var device = 'mobile';
#         var brand = 'mweb';
#     } else {
#         var device = 'desktop';
#         var brand = 'desktop';
#     }
#
#         var rsid = 'cbsi247sportssite';
#
#     if (typeof(tfsPageArena) != 'undefined') {
#         var utag_data = {
#             siteDeviceType: 'responsiveWeb|' + device,
#             siteRsids: rsid + ', cbsicbsiall',
#             sitePrimaryRsid: '' + rsid,
#             brandPlatformId: '247sports_site_' + brand,
#             siteType: 'responsive web|||' + device,
#             siteHier: 'sports|' + tfsPageArena + '|' + tfsPageType,
#             siteSection: 'sports|' + tfsPageArena + '|||' + tfsPageType + '|' + (typeof tfsSubPageType != 'undefined' ? tfsSubPageType : ""),
#             pageTitle: '' + location.pathname,
#             pageType: '' + tfsPageType,
#             userStatus: ($tfs.User.Status.toLowerCase() == 'guest' ? 'anon' : $tfs.User.Status.replace(/\+/g, '_').toLowerCase()),
#             pageViewGuid: surround.vguid,
#             userType: ($tfs.User.Status.toLowerCase() == 'guest' ? 'anon' : 'registered'),
#             userState: ($tfs.User.Activated.toLowerCase() == 'verified' ? 'authenticated' : 'not authenticated')
#         };
#     } else {
#         var utag_data = {};
#     }
#
#     if(utag_data){
#         utag_data.isAvia = true;
#     } else{
#         window.utag_data = {isAvia: true}
#     }
#
#     if ( $247Global.readCookie('247_geo') != false) {
#         utag_data.siteEdition = $247Global.readCookie('247_geo');
#     }
#
#     if (typeof(tfsNoPageView) != 'undefined') {
#         utag_data._noViewTrack = true;
#     }
#
#     var primaryName = '';
#     var articleType = 'boardpost';
#     if (typeof firstArticleJson !== 'undefined') {
#         primaryName = firstArticleJson.author.author;
#         articleType = firstArticleJson.typeString;
#     }
#
#     if (typeof($tfs.Content) != 'undefined') {
#         utag_data._articleTitle = '' + $tfs.Content.Title;
#         utag_data._authorList = '' + $tfs.Content.Author;
#         utag_data._authorPrimaryName = '' + primaryName;
#         utag_data.articlePubDate = $('.article-cnt.is-active') ? ''+$('.article-cnt.is-active').find('[data-published]').data('published') : '';
#         utag_data.contentOrigin	= 'ugc';
#         utag_data._articleId = '' + $tfs.Content.Key;
#         utag_data._articleType = articleType;
#         utag_data.isAutomated = false;
#
#         if (typeof(tfsContentTags) != 'undefined') {
#             var tagsA = ['ncaafbsecpow', 'ncaafbarmypow', 'ncaafbtraditions', 'ncaafbpowerrankings', 'luckhappens', 'ncaafbwhiparound', 'ncaafbweekendrecap', 'fubotv'];
#             var tagsB = tfsContentTags.toLowerCase().split(',');
#             var tagsC = [];
#
#             for (var i = 0; i < tagsA.length; i++) {
#                 var currentTag = tagsA[i];
#                 if (tagsB.indexOf(currentTag) > -1) {
#                     tagsC.push(currentTag);
#                 }
#             }
#             if (tagsC.length) {
#                 utag_data.trackingTags = tagsC;
#             }
#
#             if (tagsB.indexOf('audiencedevelopment') > -1) {
#                 utag_data.articleProducer = 'audience-acquisition';
#             }
#         }
#     }
#
#     //New javascript is way better.
#     if (typeof purchaseFlow !== 'undefined') {
#         if (typeof purchaseFlow.purchaseProduct !== 'undefined') {
#             utag_data.purchaseProduct = purchaseFlow.purchaseProduct;
#         }
#         if (typeof purchaseFlow.purchaseProductName !== 'undefined') {
#             utag_data.purchaseProductName = purchaseFlow.purchaseProductName;
#         }
#         if (typeof purchaseFlow.purchaseQuantity !== 'undefined') {
#             utag_data.purchaseQuantity = purchaseFlow.purchaseQuantity;
#         }
#         if (typeof purchaseFlow.purchasePrice !== 'undefined') {
#             utag_data.purchasePrice = purchaseFlow.purchasePrice;
#         }
#         if (typeof purchaseFlow.purchaseOrderId !== 'undefined') {
#             utag_data.purchaseOrderId = purchaseFlow.purchaseOrderId;
#         }
#         if (typeof purchaseFlow.eventPurchaseStart !== 'undefined') {
#             utag_data.eventPurchaseStart = purchaseFlow.eventPurchaseStart;
#         }
#         if (typeof purchaseFlow.eventPurchaseSuccess !== 'undefined') {
#             utag_data.eventPurchaseSuccess = purchaseFlow.eventPurchaseSuccess;
#         }
#     }
#
#
#     if (typeof tfsPageSite !== 'undefined' && typeof tfsPageArena !== 'undefined') {
#         utag_data.teamName = tfsPageSite;
#         utag_data.teamId = $tfs.CurrentSite.Key;
#         utag_data.teamArena = tfsPageArena;
#     }
#     if ($tfs.User.Status != 'Guest') {
#         utag_data.userId = ''+$tfs.User.Key;
#     }
#
#
# </script>
#
# <script>
#     // Call to load tealium
#
#         var env = 'prod';
#
#         (function(a,b,c,d){
#             a='//tags.tiqcdn.com/utag/cbsi/247sportssite/' + env + '/utag.js';
#             b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.defer=true;
#             a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
#         })();
# </script>
#
# <!-- Calling Score Strip -->
# <script type="text/plain" class="optanon-category-5" async src="https://sportsfly.cbsistatic.com/bundles/sportsmediajs/js-build/common/iframe-embed-saag.js?v=1"></script>
#
# <script type="text/plain" class="optanon-category-4">
#     /*
#         Ad block code
#         Wrapper for CBS Interactive (CBSi), generated on 2019-02-19T15:08:18-05:00
#     */
#     (function() {
#         var w = window;
#         var h = 'clarium.global.ssl.fastly.net';
#         w._clrm = w._clrm || {};
#         w._clrm.gpt = {
#             propertyId: '6NAGEHPQTIMciZyoLrUIDQZlmus',
#             confiantCdn: h,
#             sandbox: 0,
#             mapping: 'W3siaSI6MiwidCI6Int7b319Ont7d319eHt7aH19IiwicCI6MCwiRCI6MSwiciI6W119LHsiaSI6NiwidCI6Int7Y299fTp7e3d9fXh7e2h9fSIsInAiOjUwLCJEIjowLCJyIjpbeyJ0IjoiZXgiLCJzIjpudWxsLCJ2IjoiY28ifV19XQ==',
#             activation: '|||Mjk0NzQxMTI5,|||NDg3ODgwNDA5,|||NDg2MzExNzY5,|||NDM1NzMyNzg3,|||MTMxNDE0MDQ5,|||MTQwOTcxNTY5,|||MTYzNDY0ODQ5,|||NDY1NzIzODQ5,|||MjEwMzQ0MjAxNQ==,|||NDQ2MzI2MzI5,|||MjE3NTUxNTQwMQ==,|||MjE3NTYzNjIwNg==,|||MjE3NTYzNzE2MA==,|||MjE3NTY2NjE3MA==,|||MzE2MTkwMTY5,|||NDU2MTk1NzI5,|||NDcxMTI3NDQ5,|||MjE3MDc2Njg1Mg==,|||MjQwMTU4MDg2NA==,|||MzQ0NjI2MDg5,|||NDkwNTg2NDA5,|||NDkwNTg2NjQ5,|||NDkwNTg2ODg5,|||NDg1MzMxMzY5,|||MjE0OTMwMTczNA==,|||MjE0OTM2NTUyNA==,|||MjE0OTM5OTQzMA==,|||MjE0OTQxMTY0NA==,|||MjE0OTQ0MTExMw==,|||MjE2NDI0MTQ4Mg==,|||MjE2NDQ1OTEzOQ==,|||NDkxMDQzMTI5,|||NDkxMDQ1MDQ5,|||NDkxMDQ2MDA5,|||NDkxMDQ2NDg5,|||NDkxMDQ2NzI5,|co|ex|MQ==',
#             callback: function(blockingType, blockingId, isBlocked, wrapperId, tagId, impressionData) {
#                 console.log("w00t one more bad ad nixed.", arguments);
#             }
#         };
#         var e = document.createElement('script');
#         e.async = true;
#         e.src = '//' + h + '/gpt/a/wrap.js?v2_1';
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(e, s);
#     })();
# </script>
#
# <!-- Third Party Scripts loaded by CMP -->
# <script defer src="https://platform.twitter.com/widgets.js" type="text/plain" class="optanon-category-5"></script>
# <script defer src="https://platform.instagram.com/en_US/embeds.js" type="text/plain" class="optanon-category-5"></script>
# </body>
# </html>

# %%
# parser-lxml = Change html to Python friendly format
#     <ul class="rankings-page__list" data-js="rankings-list">
# Obtain page's information

soup = BeautifulSoup(page.text, 'lxml')

# %%
my_div = soup.find(class_="rankings-page__list").find_all(class_="rankings-page__list-item")
my_div
# Out:
# [<li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      1
#
#                  </div>
#  <div class="other">1</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Alabama" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/592/649/4649592.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Alabama"/><noscript><img alt="Alabama" src="https://s3media.247sports.com/Uploads/Assets/592/649/4649592.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Alabama"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/alabama/Season/2021-Football/Commits/">Alabama
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/alabama/Season/2021-Football/Commits/">27 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  95.07
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="gold">
#                      7
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      18
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          2
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/alabama/Season/2021-Football/Commits/">327.80
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148753?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      2
#
#                  </div>
#  <div class="other">2</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Ohio State" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/330/917/8917330.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Ohio State"/><noscript><img alt="Ohio State" src="https://s3media.247sports.com/Uploads/Assets/330/917/8917330.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Ohio State"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/ohio-state/Season/2021-Football/Commits/">Ohio State
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/ohio-state/Season/2021-Football/Commits/">23 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  95.05
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="gold">
#                      7
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      14
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          2
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/ohio-state/Season/2021-Football/Commits/">321.78
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148716?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      3
#
#                  </div>
#  <div class="other">4</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="LSU" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/869/32/8032869.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="LSU"/><noscript><img alt="LSU" src="https://s3media.247sports.com/Uploads/Assets/869/32/8032869.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="LSU"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/lsu/Season/2021-Football/Commits/">LSU
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/lsu/Season/2021-Football/Commits/">23 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  92.89
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="gold">
#                      2
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      16
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          5
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/lsu/Season/2021-Football/Commits/">295.97
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148548?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      4
#
#                  </div>
#  <div class="other">3</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Georgia" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/605/649/4649605.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Georgia"/><noscript><img alt="Georgia" src="https://s3media.247sports.com/Uploads/Assets/605/649/4649605.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Georgia"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/georgia/Season/2021-Football/Commits/">Georgia
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/georgia/Season/2021-Football/Commits/">20 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  93.59
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="gold">
#                      4
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      12
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          4
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/georgia/Season/2021-Football/Commits/">294.80
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148547?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      5
#
#                  </div>
#  <div class="other">5</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Clemson" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/565/682/4682565.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Clemson"/><noscript><img alt="Clemson" src="https://s3media.247sports.com/Uploads/Assets/565/682/4682565.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Clemson"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/clemson/Season/2021-Football/Commits/">Clemson
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/clemson/Season/2021-Football/Commits/">19 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  94.05
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="gold">
#                      3
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      15
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          1
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/clemson/Season/2021-Football/Commits/">291.17
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148549?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      6
#
#                  </div>
#  <div class="other">6</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Oregon" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/446/649/4649446.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Oregon"/><noscript><img alt="Oregon" src="https://s3media.247sports.com/Uploads/Assets/446/649/4649446.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Oregon"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/oregon/Season/2021-Football/Commits/">Oregon
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/oregon/Season/2021-Football/Commits/">23 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  92.48
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      19
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          4
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/oregon/Season/2021-Football/Commits/">287.67
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148550?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      7
#
#                  </div>
#  <div class="other">8</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="USC" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/624/114/8114624.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="USC"/><noscript><img alt="USC" src="https://s3media.247sports.com/Uploads/Assets/624/114/8114624.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="USC"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/usc/Season/2021-Football/Commits/">USC
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/usc/Season/2021-Football/Commits/">22 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  91.98
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="silver">
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      16
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          5
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/usc/Season/2021-Football/Commits/">281.92
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148552?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      8
#
#                  </div>
#  <div class="other">7</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Texas A&amp;M" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/634/649/4649634.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Texas A&amp;M"/><noscript><img alt="Texas A&amp;M" src="https://s3media.247sports.com/Uploads/Assets/634/649/4649634.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Texas A&amp;M"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/texas-am/Season/2021-Football/Commits/">Texas A&amp;M
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/texas-am/Season/2021-Football/Commits/">23 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  91.92
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="silver">
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      16
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          6
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/texas-am/Season/2021-Football/Commits/">280.49
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148551?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      9
#
#                  </div>
#  <div class="other">10</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Notre Dame" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/207/648/4648207.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Notre Dame"/><noscript><img alt="Notre Dame" src="https://s3media.247sports.com/Uploads/Assets/207/648/4648207.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Notre Dame"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/notre-dame/Season/2021-Football/Commits/">Notre Dame
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/notre-dame/Season/2021-Football/Commits/">27 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  89.94
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      14
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          13
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/notre-dame/Season/2021-Football/Commits/">270.65
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148554?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      10
#
#                  </div>
#  <div class="other">9</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Oklahoma" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/285/648/4648285.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Oklahoma"/><noscript><img alt="Oklahoma" src="https://s3media.247sports.com/Uploads/Assets/285/648/4648285.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Oklahoma"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/oklahoma/Season/2021-Football/Commits/">Oklahoma
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/oklahoma/Season/2021-Football/Commits/">16 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  93.35
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="silver">
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      12
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          3
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/oklahoma/Season/2021-Football/Commits/">268.95
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148553?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      11
#
#                  </div>
#  <div class="other">12</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Miami" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/201/648/4648201.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Miami"/><noscript><img alt="Miami" src="https://s3media.247sports.com/Uploads/Assets/201/648/4648201.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Miami"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/miami/Season/2021-Football/Commits/">Miami
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/miami/Season/2021-Football/Commits/">23 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  90.73
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="gold">
#                      2
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      12
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          8
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/miami/Season/2021-Football/Commits/">267.59
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148556?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      12
#
#                  </div>
#  <div class="other">13</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Florida" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/863/84/11084863.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Florida"/><noscript><img alt="Florida" src="https://s3media.247sports.com/Uploads/Assets/863/84/11084863.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Florida"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/florida/Season/2021-Football/Commits/">Florida
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/florida/Season/2021-Football/Commits/">23 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  90.51
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="silver">
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      15
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          7
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/florida/Season/2021-Football/Commits/">264.13
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148557?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      13
#
#                  </div>
#  <div class="other">14</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Michigan" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/794/510/10510794.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Michigan"/><noscript><img alt="Michigan" src="https://s3media.247sports.com/Uploads/Assets/794/510/10510794.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Michigan"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/michigan/Season/2021-Football/Commits/">Michigan
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/michigan/Season/2021-Football/Commits/">22 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  90.21
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="silver">
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      11
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          10
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/michigan/Season/2021-Football/Commits/">262.15
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148558?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      14
#
#                  </div>
#  <div class="other">11</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="North Carolina" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/602/120/8120602.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="North Carolina"/><noscript><img alt="North Carolina" src="https://s3media.247sports.com/Uploads/Assets/602/120/8120602.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="North Carolina"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/north-carolina/Season/2021-Football/Commits/">North Carolina
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/north-carolina/Season/2021-Football/Commits/">24 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  91.04
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="silver">
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      12
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          6
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/north-carolina/Season/2021-Football/Commits/">257.85
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148555?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      15
#
#                  </div>
#  <div class="other">16</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Texas" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/487/456/8456487.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Texas"/><noscript><img alt="Texas" src="https://s3media.247sports.com/Uploads/Assets/487/456/8456487.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Texas"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/texas/Season/2021-Football/Commits/">Texas
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/texas/Season/2021-Football/Commits/">23 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  89.18
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="silver">
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      11
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          11
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/texas/Season/2021-Football/Commits/">248.65
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148560?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      16
#
#                  </div>
#  <div class="other">15</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Wisconsin" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/332/648/4648332.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Wisconsin"/><noscript><img alt="Wisconsin" src="https://s3media.247sports.com/Uploads/Assets/332/648/4648332.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Wisconsin"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/wisconsin/Season/2021-Football/Commits/">Wisconsin
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/wisconsin/Season/2021-Football/Commits/">21 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  89.31
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="silver">
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      8
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          12
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/wisconsin/Season/2021-Football/Commits/">243.00
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148559?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      17
#
#                  </div>
#  <div class="other">20</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Ole Miss" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/425/456/8456425.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Ole Miss"/><noscript><img alt="Ole Miss" src="https://s3media.247sports.com/Uploads/Assets/425/456/8456425.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Ole Miss"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/ole-miss/Season/2021-Football/Commits/">Ole Miss
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/ole-miss/Season/2021-Football/Commits/">25 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  88.23
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      8
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          17
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/ole-miss/Season/2021-Football/Commits/">236.71
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148536?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      18
#
#                  </div>
#  <div class="other">18</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Maryland" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/920/639/9639920.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Maryland"/><noscript><img alt="Maryland" src="https://s3media.247sports.com/Uploads/Assets/920/639/9639920.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Maryland"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/maryland/Season/2021-Football/Commits/">Maryland
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/maryland/Season/2021-Football/Commits/">24 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  87.65
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div class="silver">
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="silver">
#                      4
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          18
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/maryland/Season/2021-Football/Commits/">232.64
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148715?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      19
#
#                  </div>
#  <div class="other">21</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Auburn" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/597/649/4649597.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Auburn"/><noscript><img alt="Auburn" src="https://s3media.247sports.com/Uploads/Assets/597/649/4649597.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Auburn"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/auburn/Season/2021-Football/Commits/">Auburn
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/auburn/Season/2021-Football/Commits/">19 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  88.52
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      7
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          12
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/auburn/Season/2021-Football/Commits/">226.67
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148537?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      20
#
#                  </div>
#  <div class="other">30</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Nebraska" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/814/84/11084814.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Nebraska"/><noscript><img alt="Nebraska" src="https://s3media.247sports.com/Uploads/Assets/814/84/11084814.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Nebraska"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/nebraska/Season/2021-Football/Commits/">Nebraska
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/nebraska/Season/2021-Football/Commits/">20 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  87.96
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="silver">
#                      4
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          16
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/nebraska/Season/2021-Football/Commits/">219.73
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148538?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      21
#
#                  </div>
#  <div class="other">19</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Penn State" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/328/648/4648328.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Penn State"/><noscript><img alt="Penn State" src="https://s3media.247sports.com/Uploads/Assets/328/648/4648328.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Penn State"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/penn-state/Season/2021-Football/Commits/">Penn State
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/penn-state/Season/2021-Football/Commits/">18 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  89.36
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      7
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          9
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/penn-state/Season/2021-Football/Commits/">219.13
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148546?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      22
#
#                  </div>
#  <div class="other">24</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Tennessee" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/630/649/4649630.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Tennessee"/><noscript><img alt="Tennessee" src="https://s3media.247sports.com/Uploads/Assets/630/649/4649630.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Tennessee"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/tennessee/Season/2021-Football/Commits/">Tennessee
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/tennessee/Season/2021-Football/Commits/">17 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  88.89
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="silver">
#                      6
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          11
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/tennessee/Season/2021-Football/Commits/">219.04
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148532?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      23
#
#                  </div>
#  <div class="other">31</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Florida State" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/414/682/4682414.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Florida State"/><noscript><img alt="Florida State" src="https://s3media.247sports.com/Uploads/Assets/414/682/4682414.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Florida State"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/florida-state/Season/2021-Football/Commits/">Florida State
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/florida-state/Season/2021-Football/Commits/">17 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  88.79
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      8
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          9
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/florida-state/Season/2021-Football/Commits/">217.08
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148539?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      24
#
#                  </div>
#  <div class="other">17</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Iowa" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/539/682/4682539.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Iowa"/><noscript><img alt="Iowa" src="https://s3media.247sports.com/Uploads/Assets/539/682/4682539.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Iowa"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/iowa/Season/2021-Football/Commits/">Iowa
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/iowa/Season/2021-Football/Commits/">19 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  88.08
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="gold">
#                      7
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          12
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/iowa/Season/2021-Football/Commits/">217.01
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148561?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      25
#
#                  </div>
#  <div class="other">22</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Arkansas" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/672/698/9698672.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Arkansas"/><noscript><img alt="Arkansas" src="https://s3media.247sports.com/Uploads/Assets/672/698/9698672.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Arkansas"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/arkansas/Season/2021-Football/Commits/">Arkansas
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/arkansas/Season/2021-Football/Commits/">22 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  87.54
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="silver">
#                      4
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          18
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/arkansas/Season/2021-Football/Commits/">216.89
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148530?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      26
#
#                  </div>
#  <div class="other">26</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Missouri" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/515/682/4682515.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Missouri"/><noscript><img alt="Missouri" src="https://s3media.247sports.com/Uploads/Assets/515/682/4682515.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Missouri"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/missouri/Season/2021-Football/Commits/">Missouri
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/missouri/Season/2021-Football/Commits/">24 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  87.14
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="silver">
#                      5
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          19
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/missouri/Season/2021-Football/Commits/">214.53
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148534?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      27
#
#                  </div>
#  <div class="other">29</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Mississippi State" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/616/649/4649616.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Mississippi State"/><noscript><img alt="Mississippi State" src="https://s3media.247sports.com/Uploads/Assets/616/649/4649616.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Mississippi State"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/mississippi-state/Season/2021-Football/Commits/">Mississippi State
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/mississippi-state/Season/2021-Football/Commits/">23 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  86.46
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="silver">
#                      5
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
# ...
#  </div>
#  <div class="team-image-block">
#  <img alt="West Virginia" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/295/648/4648295.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="West Virginia"/><noscript><img alt="West Virginia" src="https://s3media.247sports.com/Uploads/Assets/295/648/4648295.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="West Virginia"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/west-virginia/Season/2021-Football/Commits/">West Virginia
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/west-virginia/Season/2021-Football/Commits/">17 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  87.54
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="silver">
#                      3
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          13
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/west-virginia/Season/2021-Football/Commits/">198.36
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148589?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      43
#
#                  </div>
#  <div class="other">49</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Stanford" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/954/472/8472954.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Stanford"/><noscript><img alt="Stanford" src="https://s3media.247sports.com/Uploads/Assets/954/472/8472954.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Stanford"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/stanford/Season/2021-Football/Commits/">Stanford
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/stanford/Season/2021-Football/Commits/">17 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  86.85
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div>
#                      2
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          15
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/stanford/Season/2021-Football/Commits/">197.73
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148595?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      44
#
#                  </div>
#  <div class="other">39</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Virginia Tech" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/212/648/4648212.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Virginia Tech"/><noscript><img alt="Virginia Tech" src="https://s3media.247sports.com/Uploads/Assets/212/648/4648212.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Virginia Tech"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/virginia-tech/Season/2021-Football/Commits/">Virginia Tech
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/virginia-tech/Season/2021-Football/Commits/">28 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  85.49
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div>
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          26
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/virginia-tech/Season/2021-Football/Commits/">195.79
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148565?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      45
#
#                  </div>
#  <div class="other">44</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Cincinnati" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/240/648/4648240.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Cincinnati"/><noscript><img alt="Cincinnati" src="https://s3media.247sports.com/Uploads/Assets/240/648/4648240.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Cincinnati"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/cincinnati/Season/2021-Football/Commits/">Cincinnati
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/cincinnati/Season/2021-Football/Commits/">24 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  85.61
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div>
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          23
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/cincinnati/Season/2021-Football/Commits/">194.99
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148590?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      46
#
#                  </div>
#  <div class="other">50</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Michigan State" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/240/483/8483240.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Michigan State"/><noscript><img alt="Michigan State" src="https://s3media.247sports.com/Uploads/Assets/240/483/8483240.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Michigan State"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/michigan-state/Season/2021-Football/Commits/">Michigan State
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/michigan-state/Season/2021-Football/Commits/">19 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  85.99
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div>
#                      2
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          17
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/michigan-state/Season/2021-Football/Commits/">194.42
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148596?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      47
#
#                  </div>
#  <div class="other">51</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Georgia Tech" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/197/648/4648197.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Georgia Tech"/><noscript><img alt="Georgia Tech" src="https://s3media.247sports.com/Uploads/Assets/197/648/4648197.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Georgia Tech"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/georgia-tech/Season/2021-Football/Commits/">Georgia Tech
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/georgia-tech/Season/2021-Football/Commits/">17 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  86.60
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="silver">
#                      3
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          14
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/georgia-tech/Season/2021-Football/Commits/">193.62
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148597?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      48
#
#                  </div>
#  <div class="other">45</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Memphis" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/244/648/4648244.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Memphis"/><noscript><img alt="Memphis" src="https://s3media.247sports.com/Uploads/Assets/244/648/4648244.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Memphis"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/memphis/Season/2021-Football/Commits/">Memphis
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/memphis/Season/2021-Football/Commits/">25 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  85.17
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          25
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/memphis/Season/2021-Football/Commits/">191.73
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148591?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      49
#
#                  </div>
#  <div class="other">57</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Vanderbilt" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/756/81/11081756.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Vanderbilt"/><noscript><img alt="Vanderbilt" src="https://s3media.247sports.com/Uploads/Assets/756/81/11081756.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Vanderbilt"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/vanderbilt/Season/2021-Football/Commits/">Vanderbilt
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/vanderbilt/Season/2021-Football/Commits/">23 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  85.12
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div>
#                      1
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          22
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/vanderbilt/Season/2021-Football/Commits/">188.27
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148584?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>,
#  <li class="rankings-page__list-item">
#  <div class="wrapper">
#  <div class="rank-column">
#  <div class="primary">
#                      50
#
#                  </div>
#  <div class="other">55</div>
#  </div>
#  <div class="team-image-block">
#  <img alt="Northwestern" class="jsonly" data-src="https://s3media.247sports.com/Uploads/Assets/266/650/7650266.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" src="https://s3media.247sports.com/Content/Img/1x1.gif" title="Northwestern"/><noscript><img alt="Northwestern" src="https://s3media.247sports.com/Uploads/Assets/266/650/7650266.png?fit=bounds&amp;crop=50:50,offset-y0.50&amp;width=50&amp;height=50&amp;fit=crop" title="Northwestern"/></noscript>
#  </div>
#  <div class="team">
#  <a class="rankings-page__name-link" href="https://247sports.com/college/northwestern/Season/2021-Football/Commits/">Northwestern
#                      </a>
#  </div>
#  <div class="total">
#  <a href="https://247sports.com/college/northwestern/Season/2021-Football/Commits/">16 Commits
#                      </a>
#  </div>
#  <div class="avg">
#                  86.58
#              </div>
#  <ul class="star-commits-list">
#  <li>
#  <h2>5-Star</h2>
#  <div>
#                      0
#                      </div>
#  </li>
#  <li>
#  <h2>4-Star</h2>
#  <div class="silver">
#                      3
#                      </div>
#  </li>
#  <li>
#  <h2>3-Star</h2>
#  <div>
#                          13
#                      </div>
#  </li>
#  </ul>
#  <div class="points">
#  <a class="number" href="https://247sports.com/college/northwestern/Season/2021-Football/Commits/">187.59
#                      </a><a aria-label="Expand" class="icon-caret-down expand-anchor" href="/InstitutionRanking/1148586?View=Detailed"></a>
#  </div>
#  </div>
#  <div data-react-container="player-ranking-flyout"></div>
#  </li>]

# %%
from bs4 import BeautifulSoup, NavigableString, Tag

teams = []

for li in my_div:
#     li = ul.find_all('li')
#     team = ul.find(class_="team")
#     print(li)
    if isinstance(li, NavigableString):
        continue
        
#     print(li)
    team_stats = []
    
    team = li.find(class_="team").text.strip()
    rank = li.find(class_="rank-column").find(class_="primary").text.strip()
    avg = li.find(class_="avg").text.strip()
    points = li.find(class_="points").text.strip()
    
    team_stats.append(team)
    team_stats.append(rank)
    team_stats.append(avg)
    team_stats.append(points)

    teams.append(team_stats)
    
#     print(f'{team} {rank} {avg} {points}')
print(teams)
# Out:
# [['Alabama', '1', '95.07', '327.80'], ['Ohio State', '2', '95.05', '321.78'], ['LSU', '3', '92.89', '295.97'], ['Georgia', '4', '93.59', '294.80'], ['Clemson', '5', '94.05', '291.17'], ['Oregon', '6', '92.48', '287.67'], ['USC', '7', '91.98', '281.92'], ['Texas A&M', '8', '91.92', '280.49'], ['Notre Dame', '9', '89.94', '270.65'], ['Oklahoma', '10', '93.35', '268.95'], ['Miami', '11', '90.73', '267.59'], ['Florida', '12', '90.51', '264.13'], ['Michigan', '13', '90.21', '262.15'], ['North Carolina', '14', '91.04', '257.85'], ['Texas', '15', '89.18', '248.65'], ['Wisconsin', '16', '89.31', '243.00'], ['Ole Miss', '17', '88.23', '236.71'], ['Maryland', '18', '87.65', '232.64'], ['Auburn', '19', '88.52', '226.67'], ['Nebraska', '20', '87.96', '219.73'], ['Penn State', '21', '89.36', '219.13'], ['Tennessee', '22', '88.89', '219.04'], ['Florida State', '23', '88.79', '217.08'], ['Iowa', '24', '88.08', '217.01'], ['Arkansas', '25', '87.54', '216.89'], ['Missouri', '26', '87.14', '214.53'], ['Mississippi State', '27', '86.46', '214.20'], ['Pittsburgh', '28', '86.98', '212.83'], ['California', '29', '87.41', '212.04'], ['Washington', '30', '88.31', '211.54'], ['Oklahoma State', '31', '86.93', '210.62'], ['UCLA', '32', '87.87', '210.04'], ['Virginia', '33', '86.34', '209.61'], ['Utah', '34', '87.57', '208.97'], ['Kentucky', '35', '87.44', '208.10'], ['NC State', '36', '86.31', '206.30'], ['Boston College', '37', '85.70', '205.24'], ['Minnesota', '38', '87.54', '203.38'], ['Rutgers', '39', '86.04', '203.17'], ['Louisville', '40', '86.26', '200.85'], ['Baylor', '41', '86.99', '200.02'], ['West Virginia', '42', '87.54', '198.36'], ['Stanford', '43', '86.85', '197.73'], ['Virginia Tech', '44', '85.49', '195.79'], ['Cincinnati', '45', '85.61', '194.99'], ['Michigan State', '46', '85.99', '194.42'], ['Georgia Tech', '47', '86.60', '193.62'], ['Memphis', '48', '85.17', '191.73'], ['Vanderbilt', '49', '85.12', '188.27'], ['Northwestern', '50', '86.58', '187.59']]

# %% [markdown]
# ## Write to csv

# %%
import csv

csv_file =open('ncaa_dump.csv', 'w', newline='')
writer = csv.writer(csv_file)

header = ['Team','Rank', 'Ave','Points']

writer.writerow(header)

try:
    for team in teams:
        print(team)
        writer.writerow(team)
finally:
    csv_file.close()
# Out:
# ['Alabama', '1', '95.07', '327.80']
# ['Ohio State', '2', '95.05', '321.78']
# ['LSU', '3', '92.89', '295.97']
# ['Georgia', '4', '93.59', '294.80']
# ['Clemson', '5', '94.05', '291.17']
# ['Oregon', '6', '92.48', '287.67']
# ['USC', '7', '91.98', '281.92']
# ['Texas A&M', '8', '91.92', '280.49']
# ['Notre Dame', '9', '89.94', '270.65']
# ['Oklahoma', '10', '93.35', '268.95']
# ['Miami', '11', '90.73', '267.59']
# ['Florida', '12', '90.51', '264.13']
# ['Michigan', '13', '90.21', '262.15']
# ['North Carolina', '14', '91.04', '257.85']
# ['Texas', '15', '89.18', '248.65']
# ['Wisconsin', '16', '89.31', '243.00']
# ['Ole Miss', '17', '88.23', '236.71']
# ['Maryland', '18', '87.65', '232.64']
# ['Auburn', '19', '88.52', '226.67']
# ['Nebraska', '20', '87.96', '219.73']
# ['Penn State', '21', '89.36', '219.13']
# ['Tennessee', '22', '88.89', '219.04']
# ['Florida State', '23', '88.79', '217.08']
# ['Iowa', '24', '88.08', '217.01']
# ['Arkansas', '25', '87.54', '216.89']
# ['Missouri', '26', '87.14', '214.53']
# ['Mississippi State', '27', '86.46', '214.20']
# ['Pittsburgh', '28', '86.98', '212.83']
# ['California', '29', '87.41', '212.04']
# ['Washington', '30', '88.31', '211.54']
# ['Oklahoma State', '31', '86.93', '210.62']
# ['UCLA', '32', '87.87', '210.04']
# ['Virginia', '33', '86.34', '209.61']
# ['Utah', '34', '87.57', '208.97']
# ['Kentucky', '35', '87.44', '208.10']
# ['NC State', '36', '86.31', '206.30']
# ['Boston College', '37', '85.70', '205.24']
# ['Minnesota', '38', '87.54', '203.38']
# ['Rutgers', '39', '86.04', '203.17']
# ['Louisville', '40', '86.26', '200.85']
# ['Baylor', '41', '86.99', '200.02']
# ['West Virginia', '42', '87.54', '198.36']
# ['Stanford', '43', '86.85', '197.73']
# ['Virginia Tech', '44', '85.49', '195.79']
# ['Cincinnati', '45', '85.61', '194.99']
# ['Michigan State', '46', '85.99', '194.42']
# ['Georgia Tech', '47', '86.60', '193.62']
# ['Memphis', '48', '85.17', '191.73']
# ['Vanderbilt', '49', '85.12', '188.27']
# ['Northwestern', '50', '86.58', '187.59']
